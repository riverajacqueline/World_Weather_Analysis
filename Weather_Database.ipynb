# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps
import requests
import time
import json
from datetime import datetime
from config import g_key
from config import weather_api_key

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
#Create a list for holding the cities
cities = []

# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 615

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval.     ")
print('------------------------------')

# Create counters.
record_count = 1
set_count = 1

#Loop through all the cities in our list
for i, city in enumerate(cities):
    
     # Group cities in sets of 50 for logging purposes.
    if(i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
     # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    try:
        #Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather description": weather_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval.
# ------------------------------
# Processing Record 1 of Set 1 | zhigansk
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | cidreira
# Processing Record 4 of Set 1 | chara
# Processing Record 5 of Set 1 | los llanos de aridane
# Processing Record 6 of Set 1 | hilo
# Processing Record 7 of Set 1 | mosquera
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | puerto ayora
# Processing Record 10 of Set 1 | cape town
# Processing Record 11 of Set 1 | hobart
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | thinadhoo
# Processing Record 14 of Set 1 | asau
# Processing Record 15 of Set 1 | clyde river
# Processing Record 16 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 1 | tezu
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | haines junction
# Processing Record 20 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | honiara
# Processing Record 23 of Set 1 | guangyuan
# Processing Record 24 of Set 1 | tuktoyaktuk
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | ribeira grande
# Processing Record 27 of Set 1 | qaanaaq
# Processing Record 28 of Set 1 | bereda
# Processing Record 29 of Set 1 | margate
# Processing Record 30 of Set 1 | upernavik
# Processing Record 31 of Set 1 | cheuskiny
# City not found. Skipping...
# Processing Record 32 of Set 1 | evensk
# Processing Record 33 of Set 1 | zimmi
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | otjimbingwe
# Processing Record 36 of Set 1 | taksony
# Processing Record 37 of Set 1 | hailar
# Processing Record 38 of Set 1 | avarua
# Processing Record 39 of Set 1 | dikson
# Processing Record 40 of Set 1 | fortuna
# Processing Record 41 of Set 1 | russell
# Processing Record 42 of Set 1 | talnakh
# Processing Record 43 of Set 1 | butaritari
# Processing Record 44 of Set 1 | araouane
# Processing Record 45 of Set 1 | kovur
# Processing Record 46 of Set 1 | litoral del san juan
# City not found. Skipping...
# Processing Record 47 of Set 1 | shelburne
# Processing Record 48 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 1 | barrow
# Processing Record 50 of Set 1 | ushuaia
# Processing Record 1 of Set 2 | nishihara
# Processing Record 2 of Set 2 | luena
# Processing Record 3 of Set 2 | hermanus
# Processing Record 4 of Set 2 | arraial do cabo
# Processing Record 5 of Set 2 | olden
# Processing Record 6 of Set 2 | castro
# Processing Record 7 of Set 2 | cayenne
# Processing Record 8 of Set 2 | longyearbyen
# Processing Record 9 of Set 2 | hualmay
# Processing Record 10 of Set 2 | cabo san lucas
# Processing Record 11 of Set 2 | bluff
# Processing Record 12 of Set 2 | pevek
# Processing Record 13 of Set 2 | severo-kurilsk
# Processing Record 14 of Set 2 | murray bridge
# Processing Record 15 of Set 2 | andselv
# City not found. Skipping...
# Processing Record 16 of Set 2 | baykit
# Processing Record 17 of Set 2 | luderitz
# Processing Record 18 of Set 2 | hami
# Processing Record 19 of Set 2 | yugorsk
# Processing Record 20 of Set 2 | namatanai
# Processing Record 21 of Set 2 | meiktila
# Processing Record 22 of Set 2 | saldanha
# Processing Record 23 of Set 2 | norman wells
# Processing Record 24 of Set 2 | punta arenas
# Processing Record 25 of Set 2 | ponta do sol
# Processing Record 26 of Set 2 | beira
# Processing Record 27 of Set 2 | saskylakh
# Processing Record 28 of Set 2 | isiro
# Processing Record 29 of Set 2 | kapaa
# Processing Record 30 of Set 2 | odienne
# Processing Record 31 of Set 2 | mar del plata
# Processing Record 32 of Set 2 | najran
# Processing Record 33 of Set 2 | yerbogachen
# Processing Record 34 of Set 2 | husavik
# Processing Record 35 of Set 2 | hobyo
# Processing Record 36 of Set 2 | kruisfontein
# Processing Record 37 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 38 of Set 2 | chokurdakh
# Processing Record 39 of Set 2 | ahipara
# Processing Record 40 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 2 | kodiak
# Processing Record 43 of Set 2 | kirakira
# Processing Record 44 of Set 2 | whitianga
# Processing Record 45 of Set 2 | lavrentiya
# Processing Record 46 of Set 2 | marsh harbour
# Processing Record 47 of Set 2 | pangnirtung
# Processing Record 48 of Set 2 | bandarbeyla
# Processing Record 49 of Set 2 | comodoro rivadavia
# Processing Record 50 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 3 | la vega
# Processing Record 2 of Set 3 | manjacaze
# Processing Record 3 of Set 3 | shimoda
# Processing Record 4 of Set 3 | loiza
# Processing Record 5 of Set 3 | puerto quijarro
# Processing Record 6 of Set 3 | qui nhon
# Processing Record 7 of Set 3 | florida
# Processing Record 8 of Set 3 | wageningen
# Processing Record 9 of Set 3 | ballina
# Processing Record 10 of Set 3 | derzhavinsk
# Processing Record 11 of Set 3 | maridi
# Processing Record 12 of Set 3 | tura
# Processing Record 13 of Set 3 | vardo
# Processing Record 14 of Set 3 | bredasdorp
# Processing Record 15 of Set 3 | zanzibar
# Processing Record 16 of Set 3 | ostrovnoy
# Processing Record 17 of Set 3 | bethel
# Processing Record 18 of Set 3 | hithadhoo
# Processing Record 19 of Set 3 | takoradi
# Processing Record 20 of Set 3 | ketchikan
# Processing Record 21 of Set 3 | paamiut
# Processing Record 22 of Set 3 | kapoeta
# Processing Record 23 of Set 3 | port alfred
# Processing Record 24 of Set 3 | teguise
# Processing Record 25 of Set 3 | bandiagara
# Processing Record 26 of Set 3 | andenes
# Processing Record 27 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 3 | saint george
# Processing Record 29 of Set 3 | searcy
# Processing Record 30 of Set 3 | awbari
# Processing Record 31 of Set 3 | yenotayevka
# Processing Record 32 of Set 3 | codrington
# Processing Record 33 of Set 3 | nanzhou
# Processing Record 34 of Set 3 | port elizabeth
# Processing Record 35 of Set 3 | bow island
# Processing Record 36 of Set 3 | pemberton
# Processing Record 37 of Set 3 | banjarmasin
# Processing Record 38 of Set 3 | dunedin
# Processing Record 39 of Set 3 | tasiilaq
# Processing Record 40 of Set 3 | nome
# Processing Record 41 of Set 3 | yairipok
# Processing Record 42 of Set 3 | provideniya
# Processing Record 43 of Set 3 | oksbol
# Processing Record 44 of Set 3 | thompson
# Processing Record 45 of Set 3 | ancud
# Processing Record 46 of Set 3 | sitka
# Processing Record 47 of Set 3 | baghdad
# Processing Record 48 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 3 | nemuro
# Processing Record 50 of Set 3 | shchelkun
# Processing Record 1 of Set 4 | high level
# Processing Record 2 of Set 4 | kaitangata
# Processing Record 3 of Set 4 | dicabisagan
# Processing Record 4 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 6 of Set 4 | wanning
# Processing Record 7 of Set 4 | sao joao da barra
# Processing Record 8 of Set 4 | naze
# Processing Record 9 of Set 4 | isangel
# Processing Record 10 of Set 4 | cambridge
# Processing Record 11 of Set 4 | ikwiriri
# Processing Record 12 of Set 4 | carnarvon
# Processing Record 13 of Set 4 | bambous virieux
# Processing Record 14 of Set 4 | humaita
# Processing Record 15 of Set 4 | sibolga
# Processing Record 16 of Set 4 | polistena
# Processing Record 17 of Set 4 | leh
# Processing Record 18 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 19 of Set 4 | buala
# Processing Record 20 of Set 4 | yellowknife
# Processing Record 21 of Set 4 | awjilah
# Processing Record 22 of Set 4 | dandong
# Processing Record 23 of Set 4 | khani
# Processing Record 24 of Set 4 | disraeli
# Processing Record 25 of Set 4 | aklavik
# Processing Record 26 of Set 4 | vostok
# Processing Record 27 of Set 4 | waipawa
# Processing Record 28 of Set 4 | ambon
# Processing Record 29 of Set 4 | bengkulu
# Processing Record 30 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 31 of Set 4 | zhezkazgan
# Processing Record 32 of Set 4 | airai
# Processing Record 33 of Set 4 | superior
# Processing Record 34 of Set 4 | tautira
# Processing Record 35 of Set 4 | brae
# Processing Record 36 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 4 | prince rupert
# Processing Record 39 of Set 4 | chapais
# Processing Record 40 of Set 4 | caucaia
# Processing Record 41 of Set 4 | torbay
# Processing Record 42 of Set 4 | tiksi
# Processing Record 43 of Set 4 | dombarovskiy
# Processing Record 44 of Set 4 | totness
# Processing Record 45 of Set 4 | visnes
# Processing Record 46 of Set 4 | mulege
# Processing Record 47 of Set 4 | akcakoca
# Processing Record 48 of Set 4 | roald
# Processing Record 49 of Set 4 | yaan
# Processing Record 50 of Set 4 | vastervik
# City not found. Skipping...
# Processing Record 1 of Set 5 | trofors
# Processing Record 2 of Set 5 | banda aceh
# Processing Record 3 of Set 5 | boyuibe
# Processing Record 4 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 5 | oistins
# Processing Record 6 of Set 5 | santa isabel
# Processing Record 7 of Set 5 | saint-pierre
# Processing Record 8 of Set 5 | shkotovo-22
# City not found. Skipping...
# Processing Record 9 of Set 5 | cochrane
# Processing Record 10 of Set 5 | owerri
# Processing Record 11 of Set 5 | hofn
# Processing Record 12 of Set 5 | sindand
# City not found. Skipping...
# Processing Record 13 of Set 5 | cabinda
# Processing Record 14 of Set 5 | tiznit
# Processing Record 15 of Set 5 | khatanga
# Processing Record 16 of Set 5 | buta
# Processing Record 17 of Set 5 | nanortalik
# Processing Record 18 of Set 5 | esil
# Processing Record 19 of Set 5 | hasaki
# Processing Record 20 of Set 5 | port-gentil
# Processing Record 21 of Set 5 | lebu
# Processing Record 22 of Set 5 | mayo
# Processing Record 23 of Set 5 | uvat
# Processing Record 24 of Set 5 | linares
# Processing Record 25 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 5 | semnan
# Processing Record 27 of Set 5 | atasu
# Processing Record 28 of Set 5 | faanui
# Processing Record 29 of Set 5 | sikasso
# Processing Record 30 of Set 5 | launceston
# Processing Record 31 of Set 5 | kothi
# Processing Record 32 of Set 5 | wagar
# Processing Record 33 of Set 5 | canavieiras
# Processing Record 34 of Set 5 | matara
# Processing Record 35 of Set 5 | samatau
# City not found. Skipping...
# Processing Record 36 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 37 of Set 5 | laguna
# Processing Record 38 of Set 5 | rio gallegos
# Processing Record 39 of Set 5 | mitchell
# Processing Record 40 of Set 5 | calvinia
# Processing Record 41 of Set 5 | cervo
# Processing Record 42 of Set 5 | half moon bay
# Processing Record 43 of Set 5 | saint-augustin
# Processing Record 44 of Set 5 | myrtle beach
# Processing Record 45 of Set 5 | souillac
# Processing Record 46 of Set 5 | nangong
# Processing Record 47 of Set 5 | manzhouli
# Processing Record 48 of Set 5 | mahebourg
# Processing Record 49 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 50 of Set 5 | east london
# Processing Record 1 of Set 6 | balkhash
# Processing Record 2 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 3 of Set 6 | amazar
# Processing Record 4 of Set 6 | ilulissat
# Processing Record 5 of Set 6 | lompoc
# Processing Record 6 of Set 6 | meulaboh
# Processing Record 7 of Set 6 | iqaluit
# Processing Record 8 of Set 6 | puri
# Processing Record 9 of Set 6 | tavira
# Processing Record 10 of Set 6 | ucluelet
# Processing Record 11 of Set 6 | pangai
# Processing Record 12 of Set 6 | homer
# Processing Record 13 of Set 6 | turkistan
# Processing Record 14 of Set 6 | plettenberg bay
# Processing Record 15 of Set 6 | omboue
# Processing Record 16 of Set 6 | rocha
# Processing Record 17 of Set 6 | vicuna
# Processing Record 18 of Set 6 | eyl
# Processing Record 19 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 6 | jackson
# Processing Record 21 of Set 6 | kununurra
# Processing Record 22 of Set 6 | berlevag
# Processing Record 23 of Set 6 | nikolskoye
# Processing Record 24 of Set 6 | san fernando
# Processing Record 25 of Set 6 | obo
# Processing Record 26 of Set 6 | trelew
# Processing Record 27 of Set 6 | avera
# Processing Record 28 of Set 6 | makakilo city
# Processing Record 29 of Set 6 | moussoro
# Processing Record 30 of Set 6 | bowen
# Processing Record 31 of Set 6 | namibe
# Processing Record 32 of Set 6 | port hardy
# Processing Record 33 of Set 6 | harper
# Processing Record 34 of Set 6 | henderson
# Processing Record 35 of Set 6 | acajutla
# Processing Record 36 of Set 6 | port hedland
# Processing Record 37 of Set 6 | madarounfa
# Processing Record 38 of Set 6 | movileni
# Processing Record 39 of Set 6 | komsomolskiy
# Processing Record 40 of Set 6 | ilesha
# Processing Record 41 of Set 6 | sumbe
# Processing Record 42 of Set 6 | tuatapere
# Processing Record 43 of Set 6 | geraldton
# Processing Record 44 of Set 6 | burla
# Processing Record 45 of Set 6 | coihaique
# Processing Record 46 of Set 6 | chuy
# Processing Record 47 of Set 6 | saint-philippe
# Processing Record 48 of Set 6 | vila franca do campo
# Processing Record 49 of Set 6 | pangoa
# Processing Record 50 of Set 6 | portland
# Processing Record 1 of Set 7 | narsaq
# Processing Record 2 of Set 7 | tambopata
# Processing Record 3 of Set 7 | westport
# Processing Record 4 of Set 7 | aswan
# Processing Record 5 of Set 7 | mangrol
# Processing Record 6 of Set 7 | olga
# Processing Record 7 of Set 7 | atar
# Processing Record 8 of Set 7 | ust-ishim
# Processing Record 9 of Set 7 | kattivakkam
# Processing Record 10 of Set 7 | lagdo
# Processing Record 11 of Set 7 | burnie
# Processing Record 12 of Set 7 | ternate
# Processing Record 13 of Set 7 | port lincoln
# Processing Record 14 of Set 7 | shingu
# Processing Record 15 of Set 7 | fairlie
# Processing Record 16 of Set 7 | preston
# Processing Record 17 of Set 7 | sambava
# Processing Record 18 of Set 7 | algiers
# Processing Record 19 of Set 7 | kysyl-syr
# Processing Record 20 of Set 7 | valparaiso
# Processing Record 21 of Set 7 | kavaratti
# Processing Record 22 of Set 7 | san patricio
# Processing Record 23 of Set 7 | udachnyy
# Processing Record 24 of Set 7 | esperance
# Processing Record 25 of Set 7 | jalalpur pirwala
# Processing Record 26 of Set 7 | kurumkan
# Processing Record 27 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 28 of Set 7 | nantucket
# Processing Record 29 of Set 7 | kanniyakumari
# Processing Record 30 of Set 7 | klaksvik
# Processing Record 31 of Set 7 | bilibino
# Processing Record 32 of Set 7 | new norfolk
# Processing Record 33 of Set 7 | hudson bay
# Processing Record 34 of Set 7 | pisco
# Processing Record 35 of Set 7 | yulara
# Processing Record 36 of Set 7 | pierre
# Processing Record 37 of Set 7 | mardan
# Processing Record 38 of Set 7 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 39 of Set 7 | luwuk
# Processing Record 40 of Set 7 | nanning
# Processing Record 41 of Set 7 | farafangana
# Processing Record 42 of Set 7 | charters towers
# Processing Record 43 of Set 7 | hamilton
# Processing Record 44 of Set 7 | roebourne
# Processing Record 45 of Set 7 | carutapera
# Processing Record 46 of Set 7 | yar-sale
# Processing Record 47 of Set 7 | dover
# Processing Record 48 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 7 | altay
# Processing Record 50 of Set 7 | bathsheba
# Processing Record 1 of Set 8 | tual
# Processing Record 2 of Set 8 | puerto carreno
# Processing Record 3 of Set 8 | georgetown
# Processing Record 4 of Set 8 | coquimbo
# Processing Record 5 of Set 8 | juneau
# Processing Record 6 of Set 8 | henties bay
# Processing Record 7 of Set 8 | valkeala
# Processing Record 8 of Set 8 | port keats
# Processing Record 9 of Set 8 | jalu
# Processing Record 10 of Set 8 | santa maria
# Processing Record 11 of Set 8 | maarianhamina
# Processing Record 12 of Set 8 | alofi
# Processing Record 13 of Set 8 | salalah
# Processing Record 14 of Set 8 | tianpeng
# Processing Record 15 of Set 8 | alsonemedi
# Processing Record 16 of Set 8 | pontianak
# Processing Record 17 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 18 of Set 8 | broome
# Processing Record 19 of Set 8 | kieta
# Processing Record 20 of Set 8 | antofagasta
# Processing Record 21 of Set 8 | ahuimanu
# Processing Record 22 of Set 8 | slave lake
# Processing Record 23 of Set 8 | honningsvag
# Processing Record 24 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 8 | kocevje
# Processing Record 26 of Set 8 | kasangulu
# Processing Record 27 of Set 8 | berdigestyakh
# Processing Record 28 of Set 8 | pachino
# Processing Record 29 of Set 8 | vao
# Processing Record 30 of Set 8 | nexo
# Processing Record 31 of Set 8 | shellbrook
# Processing Record 32 of Set 8 | okha
# Processing Record 33 of Set 8 | cherskiy
# Processing Record 34 of Set 8 | turukhansk
# Processing Record 35 of Set 8 | vestmannaeyjar
# Processing Record 36 of Set 8 | salumbar
# Processing Record 37 of Set 8 | mercedes
# Processing Record 38 of Set 8 | sugar hill
# Processing Record 39 of Set 8 | touba
# Processing Record 40 of Set 8 | felanitx
# Processing Record 41 of Set 8 | uyuni
# Processing Record 42 of Set 8 | merauke
# Processing Record 43 of Set 8 | haicheng
# Processing Record 44 of Set 8 | faya
# Processing Record 45 of Set 8 | gurupa
# Processing Record 46 of Set 8 | svetlyy
# Processing Record 47 of Set 8 | mount gambier
# Processing Record 48 of Set 8 | amapa
# Processing Record 49 of Set 8 | imeni babushkina
# Processing Record 50 of Set 8 | oranjemund
# Processing Record 1 of Set 9 | umtata
# Processing Record 2 of Set 9 | mahanoro
# Processing Record 3 of Set 9 | youhao
# Processing Record 4 of Set 9 | saurimo
# Processing Record 5 of Set 9 | vilyuysk
# Processing Record 6 of Set 9 | kenora
# Processing Record 7 of Set 9 | victoria
# Processing Record 8 of Set 9 | ayame
# Processing Record 9 of Set 9 | kataysk
# Processing Record 10 of Set 9 | sioux lookout
# Processing Record 11 of Set 9 | pochutla
# Processing Record 12 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 9 | fare
# Processing Record 14 of Set 9 | anadyr
# Processing Record 15 of Set 9 | pontes e lacerda
# Processing Record 16 of Set 9 | finschhafen
# Processing Record 17 of Set 9 | japura
# Processing Record 18 of Set 9 | lerwick
# Processing Record 19 of Set 9 | kemijarvi
# Processing Record 20 of Set 9 | xuanhua
# Processing Record 21 of Set 9 | thunder bay
# Processing Record 22 of Set 9 | banyo
# Processing Record 23 of Set 9 | dawei
# Processing Record 24 of Set 9 | anloga
# Processing Record 25 of Set 9 | catuday
# Processing Record 26 of Set 9 | bilma
# Processing Record 27 of Set 9 | yatou
# Processing Record 28 of Set 9 | sesheke
# Processing Record 29 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 30 of Set 9 | himora
# City not found. Skipping...
# Processing Record 31 of Set 9 | deputatskiy
# Processing Record 32 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 33 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 9 | lagoa
# Processing Record 35 of Set 9 | civitavecchia
# Processing Record 36 of Set 9 | tocopilla
# Processing Record 37 of Set 9 | biltine
# Processing Record 38 of Set 9 | sao filipe
# Processing Record 39 of Set 9 | dasoguz
# Processing Record 40 of Set 9 | viedma
# Processing Record 41 of Set 9 | nouakchott
# Processing Record 42 of Set 9 | poum
# Processing Record 43 of Set 9 | lev tolstoy
# Processing Record 44 of Set 9 | vila velha
# Processing Record 45 of Set 9 | natal
# Processing Record 46 of Set 9 | kahului
# Processing Record 47 of Set 9 | sisimiut
# Processing Record 48 of Set 9 | tororo
# Processing Record 49 of Set 9 | glogow
# Processing Record 50 of Set 9 | boguchany
# Processing Record 1 of Set 10 | ozinki
# Processing Record 2 of Set 10 | riyadh
# Processing Record 3 of Set 10 | san cristobal
# Processing Record 4 of Set 10 | fairhope
# Processing Record 5 of Set 10 | mubarakpur
# Processing Record 6 of Set 10 | arman
# Processing Record 7 of Set 10 | linxia
# Processing Record 8 of Set 10 | miles city
# Processing Record 9 of Set 10 | chimbote
# Processing Record 10 of Set 10 | gat
# Processing Record 11 of Set 10 | constitucion
# Processing Record 12 of Set 10 | caxito
# Processing Record 13 of Set 10 | auki
# Processing Record 14 of Set 10 | fort nelson
# Processing Record 15 of Set 10 | soyo
# Processing Record 16 of Set 10 | dubbo
# Processing Record 17 of Set 10 | chernyshevskiy
# Processing Record 18 of Set 10 | payo
# Processing Record 19 of Set 10 | san cosme y damian
# Processing Record 20 of Set 10 | pultusk
# Processing Record 21 of Set 10 | gweru
# Processing Record 22 of Set 10 | eydhafushi
# Processing Record 23 of Set 10 | nhulunbuy
# Processing Record 24 of Set 10 | ishigaki
# Processing Record 25 of Set 10 | la ronge
# Processing Record 26 of Set 10 | sistranda
# Processing Record 27 of Set 10 | daxian
# City not found. Skipping...
# Processing Record 28 of Set 10 | fairbanks
# Processing Record 29 of Set 10 | sigayevo
# Processing Record 30 of Set 10 | carhuamayo
# Processing Record 31 of Set 10 | riachao das neves
# Processing Record 32 of Set 10 | neyshabur
# Processing Record 33 of Set 10 | atherton
# Processing Record 34 of Set 10 | aksarka
# Processing Record 35 of Set 10 | egvekinot
# Processing Record 36 of Set 10 | shubarkuduk
# Processing Record 37 of Set 10 | beloha
# Processing Record 38 of Set 10 | itarema
# Processing Record 39 of Set 10 | washington
# Processing Record 40 of Set 10 | luanda
# Processing Record 41 of Set 10 | fontem
# Processing Record 42 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 43 of Set 10 | odweyne
# Processing Record 44 of Set 10 | west monroe
# Processing Record 45 of Set 10 | de-kastri
# Processing Record 46 of Set 10 | north vernon
# Processing Record 47 of Set 10 | bababe
# City not found. Skipping...
# Processing Record 48 of Set 10 | rosarito
# Processing Record 49 of Set 10 | bayonet point
# Processing Record 50 of Set 10 | bulaevo
# Processing Record 1 of Set 11 | curillo
# Processing Record 2 of Set 11 | kargil
# Processing Record 3 of Set 11 | vanimo
# Processing Record 4 of Set 11 | surt
# Processing Record 5 of Set 11 | deniliquin
# Processing Record 6 of Set 11 | kutum
# Processing Record 7 of Set 11 | iracoubo
# Processing Record 8 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 9 of Set 11 | chota
# Processing Record 10 of Set 11 | bongandanga
# Processing Record 11 of Set 11 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 12 of Set 11 | orlik
# Processing Record 13 of Set 11 | yamada
# Processing Record 14 of Set 11 | teya
# Processing Record 15 of Set 11 | kalabo
# Processing Record 16 of Set 11 | otjiwarongo
# Processing Record 17 of Set 11 | leningradskiy
# Processing Record 18 of Set 11 | ous
# Processing Record 19 of Set 11 | harboore
# Processing Record 20 of Set 11 | langham
# Processing Record 21 of Set 11 | santiago de chuco
# Processing Record 22 of Set 11 | pangody
# Processing Record 23 of Set 11 | havelock
# Processing Record 24 of Set 11 | kavieng
# Processing Record 25 of Set 11 | borama
# City not found. Skipping...
# Processing Record 26 of Set 11 | kyra
# Processing Record 27 of Set 11 | ixtapa
# Processing Record 28 of Set 11 | vila do maio
# Processing Record 29 of Set 11 | mokrous
# Processing Record 30 of Set 11 | copiapo
# Processing Record 31 of Set 11 | patnos
# Processing Record 32 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 33 of Set 11 | keti bandar
# Processing Record 34 of Set 11 | orsha
# Processing Record 35 of Set 11 | pocone
# Processing Record 36 of Set 11 | ariquemes
# Processing Record 37 of Set 11 | douentza
# Processing Record 38 of Set 11 | isla mujeres
# Processing Record 39 of Set 11 | kuloy
# Processing Record 40 of Set 11 | kirovskiy
# Processing Record 41 of Set 11 | constanza
# Processing Record 42 of Set 11 | tommot
# Processing Record 43 of Set 11 | nago
# Processing Record 44 of Set 11 | wajir
# Processing Record 45 of Set 11 | puerto escondido
# Processing Record 46 of Set 11 | niceville
# Processing Record 47 of Set 11 | chatrapur
# Processing Record 48 of Set 11 | vrangel
# Processing Record 49 of Set 11 | saint-francois
# Processing Record 50 of Set 11 | black river
# Processing Record 1 of Set 12 | merrill
# Processing Record 2 of Set 12 | pervomayskiy
# Processing Record 3 of Set 12 | rajula
# Processing Record 4 of Set 12 | onda
# Processing Record 5 of Set 12 | krasnoselkup
# Processing Record 6 of Set 12 | srednekolymsk
# Processing Record 7 of Set 12 | manicore
# Processing Record 8 of Set 12 | virginia beach
# Processing Record 9 of Set 12 | osorno
# Processing Record 10 of Set 12 | trairi
# Processing Record 11 of Set 12 | bintulu
# Processing Record 12 of Set 12 | mumford
# Processing Record 13 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 14 of Set 12 | moses lake
# Processing Record 15 of Set 12 | seka
# Processing Record 16 of Set 12 | buraydah
# Processing Record 17 of Set 12 | saint anthony
# Processing Record 18 of Set 12 | naples
# Processing Record 19 of Set 12 | inirida
# Processing Record 20 of Set 12 | kamenka
# Processing Record 21 of Set 12 | sorland
# Processing Record 22 of Set 12 | mangan
# Processing Record 23 of Set 12 | iberia
# Processing Record 24 of Set 12 | sorong
# Processing Record 25 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 26 of Set 12 | alekseyevsk
# Processing Record 27 of Set 12 | savannah bight
# Processing Record 28 of Set 12 | quatre cocos
# Processing Record 29 of Set 12 | mandalgovi
# Processing Record 30 of Set 12 | dudinka
# Processing Record 31 of Set 12 | queimadas
# Processing Record 32 of Set 12 | saint-leu
# Processing Record 33 of Set 12 | syracuse
# Processing Record 34 of Set 12 | havre-saint-pierre
# Processing Record 35 of Set 12 | marystown
# Processing Record 36 of Set 12 | gweta
# Processing Record 37 of Set 12 | xinqing
# Processing Record 38 of Set 12 | berlin
# Processing Record 39 of Set 12 | rangapara
# Processing Record 40 of Set 12 | guarapari
# Processing Record 41 of Set 12 | kangaatsiaq
# Processing Record 42 of Set 12 | rawson
# Processing Record 43 of Set 12 | lorengau
# Processing Record 44 of Set 12 | roura
# Processing Record 45 of Set 12 | balikpapan
# Processing Record 46 of Set 12 | antalaha
# Processing Record 47 of Set 12 | guilin
# Processing Record 48 of Set 12 | nizhniy dzhengutay
# Processing Record 49 of Set 12 | katsina
# Processing Record 50 of Set 12 | kwekwe
# Processing Record 1 of Set 13 | douai
# Processing Record 2 of Set 13 | ulladulla
# Processing Record 3 of Set 13 | santa rosalia
# Processing Record 4 of Set 13 | bosaso
# Processing Record 5 of Set 13 | amuntai
# Processing Record 6 of Set 13 | hovd
# Processing Record 7 of Set 13 | fernley
# Processing Record 8 of Set 13 | pampa
# Processing Record 9 of Set 13 | scarborough
# Processing Record 10 of Set 13 | suleja
# Processing Record 11 of Set 13 | rondonopolis
# Processing Record 12 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 13 of Set 13 | vaike-maarja
# Processing Record 14 of Set 13 | las rosas
# Processing Record 15 of Set 13 | saint-joseph
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0               Zhigansk  66.7697  123.3711     30.16        89           7
# 1                 Albany  42.6001  -73.9662     75.02        80          89
# 2               Cidreira -30.1811  -50.2056     63.95        94          98
# 3                  Chara  56.9064  118.2631     35.91        94         100
# 4  Los Llanos De Aridane  28.6585  -17.9182     67.75        75         100
# 5                   Hilo  19.7297 -155.0900     78.28        92         100
# 6               Mosquera   4.7059  -74.2302     62.69        59          75
# 7                  Vaini -21.2000 -175.2000     77.16       100          75
# 8           Puerto Ayora  -0.7393  -90.3518     78.76        91          99
# 9              Cape Town -33.9258   18.4232     62.89        86          50
#
#    Wind Speed Country Weather description                 Date
# 0       11.10      RU           clear sky  2022-05-28 17:06:56
# 1       10.27      US     overcast clouds  2022-05-28 17:06:32
# 2        4.41      BR     overcast clouds  2022-05-28 17:06:57
# 3        4.36      RU          light rain  2022-05-28 17:06:57
# 4        8.01      ES     overcast clouds  2022-05-28 17:06:57
# 5        6.91      US     overcast clouds  2022-05-28 17:06:58
# 6       14.97      CO       broken clouds  2022-05-28 17:06:58
# 7        5.75      TO       broken clouds  2022-05-28 17:06:59
# 8        8.99      EC     overcast clouds  2022-05-28 17:06:59
# 9        8.01      ZA    scattered clouds  2022-05-28 17:06:59

# %%
new_column_order = ["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Weather description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                       City Country                 Date      Lat       Lng  \
# 0                 Zhigansk      RU  2022-05-28 17:06:56  66.7697  123.3711
# 1                   Albany      US  2022-05-28 17:06:32  42.6001  -73.9662
# 2                 Cidreira      BR  2022-05-28 17:06:57 -30.1811  -50.2056
# 3                    Chara      RU  2022-05-28 17:06:57  56.9064  118.2631
# 4    Los Llanos De Aridane      ES  2022-05-28 17:06:57  28.6585  -17.9182
# ..                     ...     ...                  ...      ...       ...
# 562                 Suleja      NG  2022-05-28 17:10:44   9.1758    7.1808
# 563           Rondonopolis      BR  2022-05-28 17:10:45 -16.4708  -54.6356
# 564           Vaike-Maarja      EE  2022-05-28 17:10:45  59.1264   26.2500
# 565              Las Rosas      AR  2022-05-28 17:10:45 -32.4766  -61.5804
# 566           Saint-Joseph      RE  2022-05-28 17:10:46 -21.3667   55.6167
#
#      Max Temp  Humidity  Cloudiness  Wind Speed Weather description
# 0       30.16        89           7       11.10           clear sky
# 1       75.02        80          89       10.27     overcast clouds
# 2       63.95        94          98        4.41     overcast clouds
# 3       35.91        94         100        4.36          light rain
# 4       67.75        75         100        8.01     overcast clouds
# ..        ...       ...         ...         ...                 ...
# 562     85.87        47          65        1.52       broken clouds
# 563     94.15        26           2        5.30           clear sky
# 564     46.47        97         100        5.68     overcast clouds
# 565     60.64        60          99        4.25     overcast clouds
# 566     71.98        69          70       12.08       broken clouds
#
# [567 rows x 10 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
