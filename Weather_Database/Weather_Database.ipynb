# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps
import requests
import time
import json
from datetime import datetime
from config import g_key
from config import weather_api_key

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
#Create a list for holding the cities
cities = []

# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 621

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval.     ")
print('------------------------------')

# Create counters.
record_count = 1
set_count = 1

#Loop through all the cities in our list
for i, city in enumerate(cities):
    
     # Group cities in sets of 50 for logging purposes.
    if(i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
     # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    try:
        #Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather description": weather_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval.
# ------------------------------
# Processing Record 1 of Set 1 | faanui
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | new norfolk
# Processing Record 4 of Set 1 | hamilton
# Processing Record 5 of Set 1 | qaqortoq
# Processing Record 6 of Set 1 | isiolo
# Processing Record 7 of Set 1 | port-gentil
# Processing Record 8 of Set 1 | port elizabeth
# Processing Record 9 of Set 1 | fortuna
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | comodoro rivadavia
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | cervo
# Processing Record 14 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 1 | zaton
# Processing Record 16 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 1 | iqaluit
# Processing Record 18 of Set 1 | kharan
# Processing Record 19 of Set 1 | komsomolskiy
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 1 | castro
# Processing Record 23 of Set 1 | hithadhoo
# Processing Record 24 of Set 1 | saint-philippe
# Processing Record 25 of Set 1 | mogadishu
# Processing Record 26 of Set 1 | college
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | pafos
# Processing Record 29 of Set 1 | hilo
# Processing Record 30 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 1 | polunochnoye
# Processing Record 32 of Set 1 | huarmey
# Processing Record 33 of Set 1 | roma
# Processing Record 34 of Set 1 | fairbanks
# Processing Record 35 of Set 1 | puerto ayora
# Processing Record 36 of Set 1 | san blas
# Processing Record 37 of Set 1 | kloulklubed
# Processing Record 38 of Set 1 | mataura
# Processing Record 39 of Set 1 | tiksi
# Processing Record 40 of Set 1 | alyangula
# Processing Record 41 of Set 1 | pevek
# Processing Record 42 of Set 1 | bethel
# Processing Record 43 of Set 1 | khatanga
# Processing Record 44 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 1 | butaritari
# Processing Record 46 of Set 1 | los llanos de aridane
# Processing Record 47 of Set 1 | hasaki
# Processing Record 48 of Set 1 | ascension
# Processing Record 49 of Set 1 | yulara
# Processing Record 50 of Set 1 | bambous virieux
# Processing Record 1 of Set 2 | staryy nadym
# Processing Record 2 of Set 2 | mar del plata
# Processing Record 3 of Set 2 | luderitz
# Processing Record 4 of Set 2 | avarua
# Processing Record 5 of Set 2 | kodiak
# Processing Record 6 of Set 2 | kavaratti
# Processing Record 7 of Set 2 | bredasdorp
# Processing Record 8 of Set 2 | mitu
# Processing Record 9 of Set 2 | oranjemund
# Processing Record 10 of Set 2 | tuy hoa
# Processing Record 11 of Set 2 | port augusta
# Processing Record 12 of Set 2 | sakakah
# Processing Record 13 of Set 2 | zaymishche
# Processing Record 14 of Set 2 | vaini
# Processing Record 15 of Set 2 | madikeri
# Processing Record 16 of Set 2 | arraial do cabo
# Processing Record 17 of Set 2 | constitucion
# Processing Record 18 of Set 2 | bria
# Processing Record 19 of Set 2 | thompson
# Processing Record 20 of Set 2 | yellowknife
# Processing Record 21 of Set 2 | talnakh
# Processing Record 22 of Set 2 | nikolskoye
# Processing Record 23 of Set 2 | geilo
# Processing Record 24 of Set 2 | kapaa
# Processing Record 25 of Set 2 | broken hill
# Processing Record 26 of Set 2 | makakilo city
# Processing Record 27 of Set 2 | fort nelson
# Processing Record 28 of Set 2 | jeremoabo
# Processing Record 29 of Set 2 | the valley
# Processing Record 30 of Set 2 | tecoanapa
# Processing Record 31 of Set 2 | excelsior springs
# Processing Record 32 of Set 2 | amapa
# Processing Record 33 of Set 2 | saskylakh
# Processing Record 34 of Set 2 | ponta do sol
# Processing Record 35 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 36 of Set 2 | wilmington
# Processing Record 37 of Set 2 | avera
# Processing Record 38 of Set 2 | longyearbyen
# Processing Record 39 of Set 2 | dikson
# Processing Record 40 of Set 2 | quatre cocos
# Processing Record 41 of Set 2 | carnarvon
# Processing Record 42 of Set 2 | atuona
# Processing Record 43 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 2 | peniche
# Processing Record 45 of Set 2 | chuy
# Processing Record 46 of Set 2 | tiarei
# Processing Record 47 of Set 2 | ushuaia
# Processing Record 48 of Set 2 | nueva italia de ruiz
# Processing Record 49 of Set 2 | leshukonskoye
# Processing Record 50 of Set 2 | krasnolesnyy
# Processing Record 1 of Set 3 | saryshagan
# City not found. Skipping...
# Processing Record 2 of Set 3 | salalah
# Processing Record 3 of Set 3 | kargasok
# Processing Record 4 of Set 3 | norman wells
# Processing Record 5 of Set 3 | camacha
# Processing Record 6 of Set 3 | punta arenas
# Processing Record 7 of Set 3 | tanete
# Processing Record 8 of Set 3 | turukhansk
# Processing Record 9 of Set 3 | turiacu
# Processing Record 10 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 11 of Set 3 | shebalino
# Processing Record 12 of Set 3 | cape town
# Processing Record 13 of Set 3 | fort morgan
# Processing Record 14 of Set 3 | kamen-rybolov
# Processing Record 15 of Set 3 | severodvinsk
# Processing Record 16 of Set 3 | porto nacional
# Processing Record 17 of Set 3 | tuktoyaktuk
# Processing Record 18 of Set 3 | victoria
# Processing Record 19 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 3 | mutsamudu
# City not found. Skipping...
# Processing Record 21 of Set 3 | suntar
# Processing Record 22 of Set 3 | airai
# Processing Record 23 of Set 3 | cidreira
# Processing Record 24 of Set 3 | gazli
# Processing Record 25 of Set 3 | marshall
# Processing Record 26 of Set 3 | san cristobal
# Processing Record 27 of Set 3 | tasiilaq
# Processing Record 28 of Set 3 | ufimskiy
# Processing Record 29 of Set 3 | souillac
# Processing Record 30 of Set 3 | gasa
# Processing Record 31 of Set 3 | manono
# Processing Record 32 of Set 3 | lappeenranta
# Processing Record 33 of Set 3 | tire
# Processing Record 34 of Set 3 | vangaindrano
# Processing Record 35 of Set 3 | uni
# Processing Record 36 of Set 3 | nakhon si thammarat
# Processing Record 37 of Set 3 | danjiangkou
# Processing Record 38 of Set 3 | jamestown
# Processing Record 39 of Set 3 | severo-kurilsk
# Processing Record 40 of Set 3 | barrow
# Processing Record 41 of Set 3 | cap malheureux
# Processing Record 42 of Set 3 | praia da vitoria
# Processing Record 43 of Set 3 | leningradskiy
# Processing Record 44 of Set 3 | champerico
# Processing Record 45 of Set 3 | rotifunk
# Processing Record 46 of Set 3 | pacific grove
# Processing Record 47 of Set 3 | bennington
# Processing Record 48 of Set 3 | venado tuerto
# Processing Record 49 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 3 | key west
# Processing Record 1 of Set 4 | huilong
# Processing Record 2 of Set 4 | muros
# Processing Record 3 of Set 4 | saint george
# Processing Record 4 of Set 4 | great bend
# Processing Record 5 of Set 4 | vardo
# Processing Record 6 of Set 4 | torbay
# Processing Record 7 of Set 4 | urazovo
# Processing Record 8 of Set 4 | ribeira grande
# Processing Record 9 of Set 4 | arroyo
# Processing Record 10 of Set 4 | carutapera
# Processing Record 11 of Set 4 | kaspiyskiy
# Processing Record 12 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 4 | nortelandia
# Processing Record 14 of Set 4 | walvis bay
# Processing Record 15 of Set 4 | ancud
# Processing Record 16 of Set 4 | asau
# Processing Record 17 of Set 4 | kalmunai
# Processing Record 18 of Set 4 | isangel
# Processing Record 19 of Set 4 | numan
# Processing Record 20 of Set 4 | codrington
# Processing Record 21 of Set 4 | ossora
# Processing Record 22 of Set 4 | upernavik
# Processing Record 23 of Set 4 | provideniya
# Processing Record 24 of Set 4 | ukiah
# Processing Record 25 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 26 of Set 4 | marzuq
# Processing Record 27 of Set 4 | ostrovnoy
# Processing Record 28 of Set 4 | yorosso
# Processing Record 29 of Set 4 | klaksvik
# Processing Record 30 of Set 4 | harper
# Processing Record 31 of Set 4 | san buenaventura
# Processing Record 32 of Set 4 | rouvroy
# Processing Record 33 of Set 4 | hermanus
# Processing Record 34 of Set 4 | udachnyy
# Processing Record 35 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 36 of Set 4 | boulder city
# Processing Record 37 of Set 4 | boa vista
# Processing Record 38 of Set 4 | ugoofaaru
# Processing Record 39 of Set 4 | rawson
# Processing Record 40 of Set 4 | mehamn
# Processing Record 41 of Set 4 | vila velha
# Processing Record 42 of Set 4 | belmonte
# Processing Record 43 of Set 4 | stornoway
# Processing Record 44 of Set 4 | novyy urengoy
# Processing Record 45 of Set 4 | beringovskiy
# Processing Record 46 of Set 4 | batavia
# Processing Record 47 of Set 4 | deputatskiy
# Processing Record 48 of Set 4 | kizema
# Processing Record 49 of Set 4 | saint paul
# Processing Record 50 of Set 4 | zhezkazgan
# Processing Record 1 of Set 5 | tanabe
# Processing Record 2 of Set 5 | acapulco
# Processing Record 3 of Set 5 | bilma
# Processing Record 4 of Set 5 | tuatapere
# Processing Record 5 of Set 5 | eureka
# Processing Record 6 of Set 5 | ilulissat
# Processing Record 7 of Set 5 | aklavik
# Processing Record 8 of Set 5 | saldanha
# Processing Record 9 of Set 5 | bati
# Processing Record 10 of Set 5 | baniyas
# Processing Record 11 of Set 5 | ensenada
# Processing Record 12 of Set 5 | berlevag
# Processing Record 13 of Set 5 | lagoa
# Processing Record 14 of Set 5 | sorong
# Processing Record 15 of Set 5 | kibala
# Processing Record 16 of Set 5 | katsuura
# Processing Record 17 of Set 5 | singkawang
# Processing Record 18 of Set 5 | ahipara
# Processing Record 19 of Set 5 | mandalgovi
# Processing Record 20 of Set 5 | aykhal
# Processing Record 21 of Set 5 | yate
# Processing Record 22 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 5 | saint-francois
# Processing Record 24 of Set 5 | preobrazheniye
# Processing Record 25 of Set 5 | san andres
# Processing Record 26 of Set 5 | salta
# Processing Record 27 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 5 | margate
# Processing Record 29 of Set 5 | lodja
# Processing Record 30 of Set 5 | ust-tsilma
# Processing Record 31 of Set 5 | selikhino
# Processing Record 32 of Set 5 | san ignacio
# Processing Record 33 of Set 5 | karasjok
# Processing Record 34 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 5 | lebu
# Processing Record 36 of Set 5 | mantua
# Processing Record 37 of Set 5 | nouadhibou
# Processing Record 38 of Set 5 | erin
# Processing Record 39 of Set 5 | vila franca do campo
# Processing Record 40 of Set 5 | san patricio
# Processing Record 41 of Set 5 | ambodifototra
# City not found. Skipping...
# Processing Record 42 of Set 5 | georgetown
# Processing Record 43 of Set 5 | banjarmasin
# Processing Record 44 of Set 5 | saint anthony
# Processing Record 45 of Set 5 | isla mujeres
# Processing Record 46 of Set 5 | idlib
# Processing Record 47 of Set 5 | quepos
# Processing Record 48 of Set 5 | mahebourg
# Processing Record 49 of Set 5 | hualmay
# Processing Record 50 of Set 5 | mizdah
# Processing Record 1 of Set 6 | axim
# Processing Record 2 of Set 6 | yauya
# Processing Record 3 of Set 6 | haines junction
# Processing Record 4 of Set 6 | san francisco
# Processing Record 5 of Set 6 | arman
# Processing Record 6 of Set 6 | porto velho
# Processing Record 7 of Set 6 | bengkulu
# Processing Record 8 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 6 | fuengirola
# Processing Record 10 of Set 6 | sao jose da coroa grande
# Processing Record 11 of Set 6 | nioro
# Processing Record 12 of Set 6 | barsovo
# Processing Record 13 of Set 6 | tukrah
# Processing Record 14 of Set 6 | henties bay
# Processing Record 15 of Set 6 | rio gallegos
# Processing Record 16 of Set 6 | alashtar
# City not found. Skipping...
# Processing Record 17 of Set 6 | buraydah
# Processing Record 18 of Set 6 | ybbs
# City not found. Skipping...
# Processing Record 19 of Set 6 | gambo
# Processing Record 20 of Set 6 | karera
# Processing Record 21 of Set 6 | huangnihe
# Processing Record 22 of Set 6 | castlegar
# Processing Record 23 of Set 6 | gusau
# Processing Record 24 of Set 6 | burnie
# Processing Record 25 of Set 6 | sitka
# Processing Record 26 of Set 6 | contai
# Processing Record 27 of Set 6 | nova prata
# Processing Record 28 of Set 6 | qaanaaq
# Processing Record 29 of Set 6 | inhambane
# Processing Record 30 of Set 6 | chokurdakh
# Processing Record 31 of Set 6 | kununurra
# Processing Record 32 of Set 6 | sao joao da barra
# Processing Record 33 of Set 6 | nevsehir
# Processing Record 34 of Set 6 | japura
# Processing Record 35 of Set 6 | celestun
# Processing Record 36 of Set 6 | okhotsk
# Processing Record 37 of Set 6 | galesong
# Processing Record 38 of Set 6 | longview
# Processing Record 39 of Set 6 | remontnoye
# Processing Record 40 of Set 6 | utiel
# Processing Record 41 of Set 6 | cayenne
# Processing Record 42 of Set 6 | iwanai
# Processing Record 43 of Set 6 | shunyi
# Processing Record 44 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 6 | esperance
# Processing Record 46 of Set 6 | waitara
# Processing Record 47 of Set 6 | kupang
# Processing Record 48 of Set 6 | eskasem
# City not found. Skipping...
# Processing Record 49 of Set 6 | okha
# Processing Record 50 of Set 6 | satun
# Processing Record 1 of Set 7 | cabinda
# Processing Record 2 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 3 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 7 | moose factory
# Processing Record 5 of Set 7 | varna
# Processing Record 6 of Set 7 | gouyave
# Processing Record 7 of Set 7 | kassala
# Processing Record 8 of Set 7 | lompoc
# Processing Record 9 of Set 7 | maldonado
# Processing Record 10 of Set 7 | haimen
# Processing Record 11 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 7 | zhaoqing
# Processing Record 13 of Set 7 | roebourne
# Processing Record 14 of Set 7 | trapani
# Processing Record 15 of Set 7 | cockburn town
# Processing Record 16 of Set 7 | acajutla
# Processing Record 17 of Set 7 | ligayan
# Processing Record 18 of Set 7 | atmakur
# Processing Record 19 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 20 of Set 7 | soe
# Processing Record 21 of Set 7 | grand gaube
# Processing Record 22 of Set 7 | molochnoye
# Processing Record 23 of Set 7 | narsaq
# Processing Record 24 of Set 7 | ballina
# Processing Record 25 of Set 7 | east london
# Processing Record 26 of Set 7 | nanortalik
# Processing Record 27 of Set 7 | miles city
# Processing Record 28 of Set 7 | guerrero negro
# Processing Record 29 of Set 7 | cabo san lucas
# Processing Record 30 of Set 7 | charters towers
# Processing Record 31 of Set 7 | tual
# Processing Record 32 of Set 7 | crixas
# Processing Record 33 of Set 7 | camabatela
# Processing Record 34 of Set 7 | port lincoln
# Processing Record 35 of Set 7 | hovd
# Processing Record 36 of Set 7 | kenora
# Processing Record 37 of Set 7 | lobito
# Processing Record 38 of Set 7 | viedma
# Processing Record 39 of Set 7 | pokrovsk
# Processing Record 40 of Set 7 | sao miguel do araguaia
# Processing Record 41 of Set 7 | andevoranto
# City not found. Skipping...
# Processing Record 42 of Set 7 | luanda
# Processing Record 43 of Set 7 | concordia
# Processing Record 44 of Set 7 | daru
# Processing Record 45 of Set 7 | morant bay
# Processing Record 46 of Set 7 | coquimbo
# Processing Record 47 of Set 7 | rio grande
# Processing Record 48 of Set 7 | kaitangata
# Processing Record 49 of Set 7 | linjiang
# Processing Record 50 of Set 7 | kamenka
# Processing Record 1 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 2 of Set 8 | halifax
# Processing Record 3 of Set 8 | marica
# Processing Record 4 of Set 8 | vanimo
# Processing Record 5 of Set 8 | port alfred
# Processing Record 6 of Set 8 | qasigiannguit
# Processing Record 7 of Set 8 | saryg-sep
# Processing Record 8 of Set 8 | zaplyusye
# City not found. Skipping...
# Processing Record 9 of Set 8 | gubkinskiy
# Processing Record 10 of Set 8 | shimoda
# Processing Record 11 of Set 8 | husavik
# Processing Record 12 of Set 8 | ambilobe
# Processing Record 13 of Set 8 | la union
# Processing Record 14 of Set 8 | bath
# Processing Record 15 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 16 of Set 8 | anadyr
# Processing Record 17 of Set 8 | burica
# City not found. Skipping...
# Processing Record 18 of Set 8 | snihurivka
# Processing Record 19 of Set 8 | zhigansk
# Processing Record 20 of Set 8 | cukai
# Processing Record 21 of Set 8 | tingi
# Processing Record 22 of Set 8 | kyren
# Processing Record 23 of Set 8 | flinders
# Processing Record 24 of Set 8 | bourail
# Processing Record 25 of Set 8 | carlyle
# Processing Record 26 of Set 8 | lashio
# Processing Record 27 of Set 8 | khabez
# Processing Record 28 of Set 8 | cherskiy
# Processing Record 29 of Set 8 | kiunga
# Processing Record 30 of Set 8 | hashtrud
# Processing Record 31 of Set 8 | pemba
# Processing Record 32 of Set 8 | ciudad valles
# Processing Record 33 of Set 8 | kavieng
# Processing Record 34 of Set 8 | padang
# Processing Record 35 of Set 8 | naze
# Processing Record 36 of Set 8 | coihaique
# Processing Record 37 of Set 8 | kudahuvadhoo
# Processing Record 38 of Set 8 | dwarka
# Processing Record 39 of Set 8 | sigli
# Processing Record 40 of Set 8 | seoul
# Processing Record 41 of Set 8 | vestmannaeyjar
# Processing Record 42 of Set 8 | antalaha
# Processing Record 43 of Set 8 | pangnirtung
# Processing Record 44 of Set 8 | nome
# Processing Record 45 of Set 8 | kyaikto
# Processing Record 46 of Set 8 | marsa matruh
# Processing Record 47 of Set 8 | guymon
# Processing Record 48 of Set 8 | bubaque
# Processing Record 49 of Set 8 | aswan
# Processing Record 50 of Set 8 | pajan
# Processing Record 1 of Set 9 | alofi
# Processing Record 2 of Set 9 | bathsheba
# Processing Record 3 of Set 9 | mount gambier
# Processing Record 4 of Set 9 | alice springs
# Processing Record 5 of Set 9 | pitimbu
# Processing Record 6 of Set 9 | dzhebariki-khaya
# Processing Record 7 of Set 9 | acari
# Processing Record 8 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 9 of Set 9 | buala
# Processing Record 10 of Set 9 | starobaltachevo
# Processing Record 11 of Set 9 | urrao
# Processing Record 12 of Set 9 | omsukchan
# Processing Record 13 of Set 9 | olafsvik
# Processing Record 14 of Set 9 | kyabe
# Processing Record 15 of Set 9 | takoradi
# Processing Record 16 of Set 9 | dudinka
# Processing Record 17 of Set 9 | nakajo
# City not found. Skipping...
# Processing Record 18 of Set 9 | santa marta
# Processing Record 19 of Set 9 | ola
# Processing Record 20 of Set 9 | bam
# Processing Record 21 of Set 9 | yumen
# Processing Record 22 of Set 9 | basoko
# Processing Record 23 of Set 9 | toftir
# City not found. Skipping...
# Processing Record 24 of Set 9 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 25 of Set 9 | ginda
# Processing Record 26 of Set 9 | yakima
# Processing Record 27 of Set 9 | sao filipe
# Processing Record 28 of Set 9 | xining
# Processing Record 29 of Set 9 | nishihara
# Processing Record 30 of Set 9 | gornopravdinsk
# Processing Record 31 of Set 9 | hervey bay
# Processing Record 32 of Set 9 | tanout
# Processing Record 33 of Set 9 | coahuayana
# Processing Record 34 of Set 9 | yar-sale
# Processing Record 35 of Set 9 | nampula
# Processing Record 36 of Set 9 | grootfontein
# Processing Record 37 of Set 9 | khvoynaya
# Processing Record 38 of Set 9 | wahiawa
# Processing Record 39 of Set 9 | geraldton
# Processing Record 40 of Set 9 | galeana
# Processing Record 41 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 9 | san vicente
# Processing Record 43 of Set 9 | erdenet
# Processing Record 44 of Set 9 | booue
# Processing Record 45 of Set 9 | volot
# Processing Record 46 of Set 9 | caravelas
# Processing Record 47 of Set 9 | igarka
# Processing Record 48 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 9 | onda
# Processing Record 50 of Set 9 | kawana waters
# City not found. Skipping...
# Processing Record 1 of Set 10 | sambava
# Processing Record 2 of Set 10 | tabas
# Processing Record 3 of Set 10 | mahajanga
# Processing Record 4 of Set 10 | uaua
# Processing Record 5 of Set 10 | touros
# Processing Record 6 of Set 10 | mangrol
# Processing Record 7 of Set 10 | staryy biser
# City not found. Skipping...
# Processing Record 8 of Set 10 | port hardy
# Processing Record 9 of Set 10 | monterey
# Processing Record 10 of Set 10 | vanavara
# Processing Record 11 of Set 10 | taree
# Processing Record 12 of Set 10 | hartford
# Processing Record 13 of Set 10 | hvide sande
# Processing Record 14 of Set 10 | schramberg
# Processing Record 15 of Set 10 | sulurpeta
# City not found. Skipping...
# Processing Record 16 of Set 10 | nemuro
# Processing Record 17 of Set 10 | luwuk
# Processing Record 18 of Set 10 | sabang
# Processing Record 19 of Set 10 | itigi
# Processing Record 20 of Set 10 | vitim
# Processing Record 21 of Set 10 | chegdomyn
# Processing Record 22 of Set 10 | pascagoula
# Processing Record 23 of Set 10 | athabasca
# Processing Record 24 of Set 10 | hobyo
# Processing Record 25 of Set 10 | san policarpo
# Processing Record 26 of Set 10 | twentynine palms
# Processing Record 27 of Set 10 | zaozerne
# Processing Record 28 of Set 10 | royan
# Processing Record 29 of Set 10 | marsh harbour
# Processing Record 30 of Set 10 | ahumada
# City not found. Skipping...
# Processing Record 31 of Set 10 | kieta
# Processing Record 32 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 33 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 10 | maceio
# Processing Record 35 of Set 10 | durazno
# Processing Record 36 of Set 10 | xingyi
# Processing Record 37 of Set 10 | tandil
# Processing Record 38 of Set 10 | pimentel
# Processing Record 39 of Set 10 | hambantota
# Processing Record 40 of Set 10 | tombouctou
# Processing Record 41 of Set 10 | hami
# Processing Record 42 of Set 10 | lagos
# Processing Record 43 of Set 10 | manggar
# Processing Record 44 of Set 10 | bairiki
# Processing Record 45 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 10 | valkeala
# Processing Record 47 of Set 10 | kundgol
# Processing Record 48 of Set 10 | tucumcari
# Processing Record 49 of Set 10 | maniitsoq
# Processing Record 50 of Set 10 | tsienyane
# City not found. Skipping...
# Processing Record 1 of Set 11 | banff
# Processing Record 2 of Set 11 | ardakan
# Processing Record 3 of Set 11 | lorengau
# Processing Record 4 of Set 11 | krasnoselkup
# Processing Record 5 of Set 11 | killorglin
# Processing Record 6 of Set 11 | shasta lake
# Processing Record 7 of Set 11 | horsham
# Processing Record 8 of Set 11 | cascais
# Processing Record 9 of Set 11 | san rafael
# Processing Record 10 of Set 11 | pokhara
# Processing Record 11 of Set 11 | kruisfontein
# Processing Record 12 of Set 11 | roald
# Processing Record 13 of Set 11 | picos
# Processing Record 14 of Set 11 | keetmanshoop
# Processing Record 15 of Set 11 | te anau
# Processing Record 16 of Set 11 | aksu
# Processing Record 17 of Set 11 | wollongong
# Processing Record 18 of Set 11 | korla
# Processing Record 19 of Set 11 | lavrentiya
# Processing Record 20 of Set 11 | conceicao da barra
# Processing Record 21 of Set 11 | byron bay
# Processing Record 22 of Set 11 | launceston
# Processing Record 23 of Set 11 | saint-augustin
# Processing Record 24 of Set 11 | tilichiki
# Processing Record 25 of Set 11 | kwekwe
# Processing Record 26 of Set 11 | barcelos
# Processing Record 27 of Set 11 | aksarka
# Processing Record 28 of Set 11 | labuhan
# Processing Record 29 of Set 11 | nagato
# Processing Record 30 of Set 11 | honningsvag
# Processing Record 31 of Set 11 | san juan
# Processing Record 32 of Set 11 | kedrovka
# Processing Record 33 of Set 11 | xichang
# Processing Record 34 of Set 11 | igrim
# Processing Record 35 of Set 11 | rocha
# Processing Record 36 of Set 11 | korhogo
# Processing Record 37 of Set 11 | susanville
# Processing Record 38 of Set 11 | luan
# Processing Record 39 of Set 11 | ilhabela
# Processing Record 40 of Set 11 | cameron park
# Processing Record 41 of Set 11 | mergui
# City not found. Skipping...
# Processing Record 42 of Set 11 | red wing
# Processing Record 43 of Set 11 | shingu
# Processing Record 44 of Set 11 | natal
# Processing Record 45 of Set 11 | banjar
# Processing Record 46 of Set 11 | buin
# Processing Record 47 of Set 11 | pingliang
# Processing Record 48 of Set 11 | santa isabel do rio negro
# Processing Record 49 of Set 11 | altay
# Processing Record 50 of Set 11 | maiduguri
# Processing Record 1 of Set 12 | grindavik
# Processing Record 2 of Set 12 | puqi
# Processing Record 3 of Set 12 | raul soares
# Processing Record 4 of Set 12 | kapit
# Processing Record 5 of Set 12 | jishou
# Processing Record 6 of Set 12 | fortuna foothills
# Processing Record 7 of Set 12 | betafo
# Processing Record 8 of Set 12 | puerto escondido
# Processing Record 9 of Set 12 | misratah
# Processing Record 10 of Set 12 | mayo
# Processing Record 11 of Set 12 | yatou
# Processing Record 12 of Set 12 | ambon
# Processing Record 13 of Set 12 | dubbo
# Processing Record 14 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 15 of Set 12 | hidrolandia
# Processing Record 16 of Set 12 | bom jesus
# Processing Record 17 of Set 12 | andenes
# Processing Record 18 of Set 12 | akdepe
# Processing Record 19 of Set 12 | maryville
# Processing Record 20 of Set 12 | manat
# Processing Record 21 of Set 12 | broome
# Processing Record 22 of Set 12 | laguna
# Processing Record 23 of Set 12 | catalina
# Processing Record 24 of Set 12 | wamba
# Processing Record 25 of Set 12 | palora
# Processing Record 26 of Set 12 | sulina
# Processing Record 27 of Set 12 | srednekolymsk
# Processing Record 28 of Set 12 | porto novo
# Processing Record 29 of Set 12 | jadu
# Processing Record 30 of Set 12 | lipari
# Processing Record 31 of Set 12 | banmo
# City not found. Skipping...
# Processing Record 32 of Set 12 | novikovo
# Processing Record 33 of Set 12 | wadi maliz
# Processing Record 34 of Set 12 | mount isa
# Processing Record 35 of Set 12 | goumenissa
# Processing Record 36 of Set 12 | tazovskiy
# Processing Record 37 of Set 12 | westport
# Processing Record 38 of Set 12 | san ciro de acosta
# Processing Record 39 of Set 12 | nova vicosa
# Processing Record 40 of Set 12 | bandarbeyla
# Processing Record 41 of Set 12 | goderich
# Processing Record 42 of Set 12 | nexo
# Processing Record 43 of Set 12 | tumkur
# Processing Record 44 of Set 12 | kahului
# Processing Record 45 of Set 12 | saint-pierre
# Processing Record 46 of Set 12 | campbell river
# Processing Record 47 of Set 12 | blackfoot
# Processing Record 48 of Set 12 | rio branco
# Processing Record 49 of Set 12 | jumla
# Processing Record 50 of Set 12 | khandyga
# Processing Record 1 of Set 13 | gazojak
# Processing Record 2 of Set 13 | itarema
# Processing Record 3 of Set 13 | waitati
# Processing Record 4 of Set 13 | pulandian
# Processing Record 5 of Set 13 | pisco
# Processing Record 6 of Set 13 | polson
# Processing Record 7 of Set 13 | namatanai
# Processing Record 8 of Set 13 | sur
# Processing Record 9 of Set 13 | orgun
# City not found. Skipping...
# Processing Record 10 of Set 13 | faya
# Processing Record 11 of Set 13 | andros town
# Processing Record 12 of Set 13 | pyinmana
# Processing Record 13 of Set 13 | saint combs
# City not found. Skipping...
# Processing Record 14 of Set 13 | tigil
# Processing Record 15 of Set 13 | mirador
# Processing Record 16 of Set 13 | ahmadpur east
# Processing Record 17 of Set 13 | trinidad
# Processing Record 18 of Set 13 | dandong
# Processing Record 19 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 20 of Set 13 | niamey
# Processing Record 21 of Set 13 | houma
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Faanui -16.4833 -151.7500     81.01        73          37
# 1           Bluff -46.6000  168.3333     54.81        71         100
# 2     New Norfolk -42.7826  147.0587     47.91        78          84
# 3        Hamilton  39.1834  -84.5333     71.55        79          75
# 4        Qaqortoq  60.7167  -46.0333     40.23        77          16
# 5          Isiolo   0.3546   37.5822     64.35        80          79
# 6     Port-Gentil  -0.7193    8.7815     75.87        82          98
# 7  Port Elizabeth -33.9180   25.5701     57.49        77           0
# 8         Fortuna  40.5982 -124.1573     55.65        93          75
# 9          Hobart -42.8794  147.3294     48.25        95          75
#
#    Wind Speed Country Weather description                 Date
# 0       17.00      PF          light rain  2022-05-29 00:42:49
# 1        5.95      NZ     overcast clouds  2022-05-29 00:42:49
# 2        0.74      AU       broken clouds  2022-05-29 00:42:49
# 3        0.00      US       broken clouds  2022-05-29 00:39:39
# 4        5.53      GL          few clouds  2022-05-29 00:42:50
# 5        6.55      KE       broken clouds  2022-05-29 00:42:50
# 6       14.63      GA     overcast clouds  2022-05-29 00:42:51
# 7        6.91      ZA           clear sky  2022-05-29 00:42:51
# 8       11.50      US       broken clouds  2022-05-29 00:42:51
# 9       12.66      AU                 fog  2022-05-29 00:42:52

# %%
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Weather description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Faanui      PF -16.4833 -151.7500     81.01        73          37
# 1            Bluff      NZ -46.6000  168.3333     54.81        71         100
# 2      New Norfolk      AU -42.7826  147.0587     47.91        78          84
# 3         Hamilton      US  39.1834  -84.5333     71.55        79          75
# 4         Qaqortoq      GL  60.7167  -46.0333     40.23        77          16
# ..             ...     ...      ...       ...       ...       ...         ...
# 564  Ahmadpur East      PK  29.1431   71.2598     89.76         8           0
# 565       Trinidad      BO -14.8333  -64.9000     74.91        77           1
# 566        Dandong      CN  40.1292  124.3947     63.91        86         100
# 567         Niamey      NE  13.5137    2.1098     93.49        36          20
# 568          Houma      US  29.5958  -90.7195     78.80        61          75
#
#      Wind Speed Weather description
# 0         17.00          light rain
# 1          5.95     overcast clouds
# 2          0.74       broken clouds
# 3          0.00       broken clouds
# 4          5.53          few clouds
# ..          ...                 ...
# 564       10.98           clear sky
# 565        3.71           clear sky
# 566       15.01     overcast clouds
# 567        8.05        thunderstorm
# 568        5.75       broken clouds
#
# [569 rows x 9 columns]
